# %%
from solve_pde import solve_pde
from utils import *
import sys
from run_dynamics import run_fine_lorenz, run_coarse_lorenz
from pde_model import Lorenz_Model
from dataset import dataset
import argparse

# %%
def list_scatter3d_plotly(trajs): # Plot footprints of a point trajectory
    # traj has format
    # [ x0,y0,z0; 
    #   x1,y1,z1; 
    #   ...
    #   xN,yN,zN] 
    import plotly
    import plotly.graph_objs as go
    plotly.offline.init_notebook_mode(connected=True)
    
    colorscales = ['Blues', 'Viridis']
    data = []
    for index, traj in enumerate(trajs):
        x, y, z = traj[::2,0], traj[::2,1], traj[::2,2]
        trace1 = go.Scatter3d(x=x,y=y,z=z,mode='markers',
            marker=dict(size=2, color=z, # set color to an array/list of desired values
                colorscale=colorscales[index],   # choose a colorscale
                opacity=0.8))
        data.append(trace1)
    layout = go.Layout(margin=dict(l=0,r=0,b=0,t=0))
    fig = go.Figure(data=data, layout=layout)
    plotly.offline.iplot(fig, filename='lorenz.html')

# %%
configs = load_params('lorenz_params.txt')

# %%
fine_traj = run_fine_lorenz(icpt=[1,2,8], N=1000, **configs)

# %%
coarse_traj = run_coarse_lorenz(icpt = [1, 8], N=1300, dt = 0.0001, **configs)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /Users/xiaohan.zhang/Library/Mobile Documents/com~apple~CloudDocs/Planet/Codes/axiom/python/lorenz/pde_model.py:65: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /usr/local/miniconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# xadv, G and dG shape
# (?, 2)
# (?, 1)
# (?, 2)
# (?, 1)
# ...

# %%
list_scatter3d_plotly([coarse_traj, fine_traj/configs['Bbar']])
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="753653e0-63e8-48b4-ad16-7c88306735ce" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("753653e0-63e8-48b4-ad16-7c88306735ce")) {
# ...

# %%
# print(sess.run([model.loss_sum], feed_dict={model.x_ph:np.array([[0.90048146, 0.4027747]])}))

# Gid = 1
# LOG_DIR = '/Users/xiaohan.zhang/Planet/Codes/axiom/python/lorenz/log_tb/'

# sess = tf.Session()
# sess.run(tf.global_variables_initializer())
# sess.run(tf.local_variables_initializer())

# saver = tf.train.Saver()
# saver.restore(sess, save_path=os.path.join(LOG_DIR, "Gid_"+str(Gid)+"_model.ckpt-0"))

# db = GD[Gid]
# inds = np.arange(db.shape[0])
# split = int(0.8 * len(inds))
# train_inds = inds[:split]
# valid_inds = inds[split:]

# valid = 0
# for index, ind in enumerate(valid_inds):
#     valid += sess.run([model.loss_sum], feed_dict={model.x_ph:db[ind]})[0]
# valid /= len(valid_inds)
# print("Validation mean residual = {: 5.10E}".format(valid))
